# %%
from rag_helper import K2ThinkRAG_nonhw
from ingest import load_faq_data, build_index

# %%
from dotenv import load_dotenv
load_dotenv()
from openai import OpenAI
import os

openai_client = OpenAI(
    api_key=os.getenv("OPENAI_API_KEY"),
    base_url="https://api.k2think.ai/v1"
)

# %%
documents = load_faq_data()
index = build_index(documents)

assistant = K2ThinkRAG_nonhw(index, openai_client)

# %%
assistant.rag("I just discovered the course, can i still join?")
# Out:
# '\nYes—you can still join the course. If you’d like to receive a certificate, make sure to submit your project while the platform is still accepting submissions. (You can start the lessons at any time until the final project deadline.)\n'
