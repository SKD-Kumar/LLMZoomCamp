# %%
from sqlitesearch import TextSearchIndex

sqlite_index = TextSearchIndex(
    text_fields=["question", "section", "answer"],
    keyword_fields=["course"],
    db_path="faq.db"
)

# %%
from dotenv import load_dotenv
load_dotenv()
from openai import OpenAI
import os

openai_client = OpenAI(
    api_key=os.getenv("OPENAI_API_KEY"),
    base_url="https://api.k2think.ai/v1"
)

# %%
from rag_helper import K2ThinkRAG
assistant = K2ThinkRAG(sqlite_index, openai_client)

# %%
assistant.rag("I just discoveredt the course, can i still join?")
# Out:
# '\nYes—you can still join the course. If you want to receive a certificate, you must submit your project while we’re still accepting submissions.\n'
